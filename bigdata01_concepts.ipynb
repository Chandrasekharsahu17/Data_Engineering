# %% [markdown]
# ###  Build: Draw the 5 V’s with a code cell using print() or a markdown table — make it your own cheatsheet

# %% [markdown]
# ## 5V's of Big Data
#
# ### V1 -- Volume- The amount of Data that is being Handeled (MBs,GBs,TBs) of Data
# ### V2 -- Variety - The different types of data
#         1. Structured
#                 * Tabular Kind of Data (rows and columns)
#         2. Semi Structured
#                 * all json,xml files
#         3. unstructured
#                 * files like mp3 ,mp4 ,email
# ### V3 -- Velocity - The speed at which Data being Generated
#         1. Batch - Once a month once a week kind of thing
#         2. realtime - Youtube ,instagram,Banking, credit card transcation
#         3. near real time - 2,3 minutes late the data is being generated 9paytm trancation
# ### V4 -- Veracity - How much the data is trusted and the quality of data
#                 1. we use data cleaning and validating to cleans those data
#                 2. eg - the age can be negative in a db
# ### V5 -- Values - How much the data are impacting the business decision, how much it is useful for the company

# %% [markdown]
# ## “Why can’t a single machine handle Big Data? What does ‘distributed’ actually mean?”

# %% [markdown]
# ### a single machine has limited amount of data and computing power as Big data requires much more more computing power to solve complex data s and unstructured data so single machine cant handle Big data

# %% [markdown]
# ## a single machine can handel limited amount of data and computing power as Big data requires much more more computing power and storage to solve complex data and unstructured data so single machine cant handle Big data¶
#
# ### Distibute meaning the data will be distributed along different machines which are connected so that they can handel the big data which can be on premise or cloud
