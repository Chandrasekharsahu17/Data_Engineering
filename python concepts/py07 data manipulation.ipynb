# %% [markdown]
# # 🔧 py07_data_manipulation.ipynb
# ### Phase 4 — Python for Data Engineering · Part 1
# **Topics:** Data Manipulation & Analysis · Data Source Reading
#
# ---
# ```
# 👁️  WATCH    →  Understand the concept
# ⌨️  BUILD    →  Code it yourself — no copy paste
# 🗣️  EXPLAIN  →  Write it in plain English
# ```
# ---
#
# ## 🗣️ EXPLAIN BLOCK — Fill this LAST
#
# **Q1: What is the difference between `.loc` and `.iloc`? Give a concrete scenario for each.**
#
# `YOUR ANSWER:`
#
# **Q2: When do you use `groupby` vs `pivot_table`?**
#
# `YOUR ANSWER:`
#
# **Q3: What does `apply()` do and why is it more powerful than a loop?**
#
# `YOUR ANSWER:`
#
# **Q4: What is the difference between reading a CSV vs a JSON file in Pandas?**
#
# `YOUR ANSWER:`
#
# **Q5: Why should you always check `.info()` and `.isnull().sum()` before doing any analysis?**
#
# `YOUR ANSWER:`

# %% [markdown]
# ---
# # SECTION 1 — Data Cleaning Deep Dive
# ---

# %%
import pandas as pd
import numpy as np

# ⌨️ BUILD 1 — Clean a Messy Dataset
# This is raw employee data with multiple problems

raw = pd.DataFrame({
    'emp_id':  [1, 2, 2, 3, 4, 5, 6, 6],
    'name':    ['raj sharma', 'PRIYA', 'PRIYA', 'amit k', None, 'Sneha', 'dev', 'dev'],
    'age':     [28, 250, 250, 32, 29, -5, 35, 35],   # 250 and -5 are invalid
    'salary':  [55000, 72000, 72000, None, 68000, 45000, 91000, 91000],
    'dept':    ['IT', 'HR', 'HR', 'Finance', 'IT', None, 'IT', 'IT'],
    'joining': ['2020-03-15', '2019-07-01', '2019-07-01', '2021-11-20',
                '2018-05-10', '2022-01-05', '2017-09-30', '2017-09-30']
})

# Step 1: Show all problems — nulls, duplicates, invalid ages
# YOUR CODE:

# Step 2: Drop duplicates based on emp_id
# YOUR CODE:

# Step 3: Drop rows with invalid age (age must be 18-65)
# YOUR CODE:

# Step 4: Drop rows where name is null
# YOUR CODE:

# Step 5: Fill missing salary with dept-wise median
# (hint: use groupby + transform)
# YOUR CODE:

# Step 6: Fill missing dept with 'Unknown'
# YOUR CODE:

# Step 7: Standardize name to Title Case (e.g. 'raj sharma' → 'Raj Sharma')
# YOUR CODE:

# Step 8: Convert 'joining' column to datetime
# YOUR CODE:

# Step 9: Add 'tenure_years' = how many full years since joining (use today's date)
# YOUR CODE:

# Step 10: Print final clean DataFrame and verify: no nulls, no dupes, valid ages
# YOUR CODE:

# %% [markdown]
# ## 🧠 THINK
# **Q: In Step 5, why did you use `groupby + transform` instead of `groupby + mean`? What is the difference?**
#
# `YOUR ANSWER:`
#
# **Q: You had 8 rows and ended up with fewer after cleaning. In a real pipeline with millions of rows, how do you decide whether it's safe to drop rows vs fill them?**
#
# `YOUR ANSWER:`

# %% [markdown]
# ---
# # SECTION 2 — Advanced Filtering & Transformation
# ---

# %%
# ⌨️ BUILD 2 — apply() for complex transformations
# Using your cleaned employee DataFrame:

# 1. Add 'salary_band' using apply():
#    salary >= 80000 → 'A'
#    salary >= 60000 → 'B'
#    salary >= 40000 → 'C'
#    else → 'D'
# YOUR CODE:


# 2. Add 'experience_level' using apply() on tenure_years:
#    >= 5 → 'Senior'
#    >= 2 → 'Mid'
#    else → 'Junior'
# YOUR CODE:


# 3. Apply a custom function using apply() on MULTIPLE columns:
#    'performance_score' = (salary / 1000) + (tenure_years * 2)
#    Use axis=1 to apply row-wise
# YOUR CODE:

# %%
# ⌨️ BUILD 3 — String Operations
# Create a Series of messy email addresses

emails = pd.Series([
    '  Raj.Sharma@Gmail.COM  ',
    'priya123@YAHOO.com',
    'AMIT.K@outlook.com  ',
    'sneha@company.IN',
    None
])

# 1. Strip whitespace from all emails
# YOUR CODE:

# 2. Lowercase everything
# YOUR CODE:

# 3. Extract the domain (part after @)
# YOUR CODE:

# 4. Check if email contains 'gmail' → return True/False
# YOUR CODE:

# 5. Drop the None email
# YOUR CODE:

# %% [markdown]
# ---
# # SECTION 3 — GroupBy & Aggregation
# ---

# %%
# ⌨️ BUILD 4 — GroupBy with agg()
# Using the cleaned employee DataFrame:

# 1. Group by dept → get count, mean salary, max salary, min tenure
#    Use .agg() with a dictionary to get all in one call
# YOUR CODE:


# 2. Group by dept AND experience_level → get average performance_score
# YOUR CODE:


# 3. Find the top earner in each department
#    (hint: groupby + idxmax or sort + head)
# YOUR CODE:


# 4. Find departments where average salary > overall average salary
# YOUR CODE:

# %%
# ⌨️ BUILD 5 — pivot_table vs groupby
# Use the cleaned employee df

# 1. Create a pivot table:
#    rows = dept, columns = experience_level
#    values = salary, aggfunc = mean
# YOUR CODE:


# 2. Do the same thing using groupby
# YOUR CODE:


# 3. Write a comment: when would you prefer pivot_table over groupby?
# YOUR COMMENT:

# %% [markdown]
# ---
# # SECTION 4 — Reading from Multiple Sources
# ---

# %%
# ⌨️ BUILD 6 — Save and Read: CSV, JSON, Excel
# Use your cleaned employee DataFrame

# 1. Save to CSV (no index)
# YOUR CODE:

# 2. Save to JSON (records format)
# YOUR CODE:

# 3. Read CSV back → print shape and dtypes
# YOUR CODE:

# 4. Read JSON back → print shape and dtypes
# YOUR CODE:

# 5. Compare dtypes of CSV vs JSON read
#    Are datetime columns preserved? Write a comment.
# YOUR CODE & COMMENT:

# %%
# ⌨️ BUILD 7 — Reading with options
# Create a CSV manually with some edge cases and practice reading it correctly

import os

# Write a tricky CSV file to disk
tricky_csv = """# This is a comment line
emp_id,name,salary,active
1,Raj,55000,yes
2,Priya,72000,no
3,Amit,68000,yes
4,Sneha,N/A,yes
5,Dev,91000,no
"""
with open('tricky.csv', 'w') as f:
    f.write(tricky_csv)

# Now read it properly:
# 1. Skip the comment line (skiprows)
# YOUR CODE:

# 2. Treat 'N/A' as NaN (na_values)
# YOUR CODE:

# 3. Convert 'active' column: yes→True, no→False
# YOUR CODE:

# 4. Print final clean result
# YOUR CODE:

# %% [markdown]
# ## 🧠 THINK — Data Source Reading
#
# **Q: You get a CSV from a client where dates are in format 'DD/MM/YYYY'. How do you read it correctly into Pandas?**
#
# `YOUR ANSWER:`
#
# **Q: A JSON file has nested objects (e.g. address has city, state, pincode as sub-fields). How would you flatten it into a normal DataFrame?**
#
# `YOUR ANSWER:`
#
# **Q: What is `chunksize` in `pd.read_csv()`? When would you use it?**
#
# `YOUR ANSWER:`

# %% [markdown]
# ---
# # 🏋️ PRACTICE TASKS
# ---

# %%
# Practice Task 1 — Full Sales Pipeline
# You are a Data Engineer at a retail company.
# Here is messy raw sales data:

sales_raw = pd.DataFrame({
    'order_id':   [101, 102, 102, 103, 104, 105, 106, 107, 108],
    'customer':   ['Raj', 'Priya', 'Priya', 'Amit', None, 'Sneha', 'Dev', 'Aisha', 'Kabir'],
    'product':    ['Laptop', 'Phone', 'Phone', 'Tablet', 'Laptop', 'Earbuds', None, 'Laptop', 'Phone'],
    'category':   ['Electronics', 'Electronics', 'Electronics', 'Electronics',
                   'Electronics', 'Accessories', 'Electronics', 'Electronics', 'Electronics'],
    'qty':        [1, 2, 2, 1, 1, 3, 1, 2, 1],
    'unit_price': [75000, 25000, 25000, 40000, -500, 3000, 75000, 75000, 25000],
    'order_date': ['2024-01-15', '2024-01-20', '2024-01-20', '2024-02-05',
                   '2024-02-10', '2024-02-18', '2024-03-01', '2024-03-15', '2024-03-20']
})

# Your pipeline (do ALL steps):
# Step 1: Find and report all data quality issues
# Step 2: Remove duplicates (by order_id)
# Step 3: Remove rows with null customer or product
# Step 4: Remove rows with invalid unit_price (negative)
# Step 5: Convert order_date to datetime
# Step 6: Add 'revenue' = qty * unit_price
# Step 7: Add 'month' extracted from order_date
# Step 8: Add 'revenue_with_gst' = revenue * 1.18
# Step 9: Group by product → total revenue, total qty, avg unit_price
# Step 10: Group by month → total revenue per month
# Step 11: Find the top 2 products by revenue
# Step 12: Save cleaned data to 'sales_clean.csv'

# YOUR CODE:

# %%
# Practice Task 2 — Read and Combine Multiple Sources
# Step 1: Save sales_raw (cleaned) to CSV
# Step 2: Create a separate DataFrame 'discounts' with columns:
#         product, discount_pct (e.g. Laptop: 0.10, Phone: 0.05)
# Step 3: Save discounts to JSON
# Step 4: Read both back from files
# Step 5: Merge them on 'product'
# Step 6: Add 'final_revenue' = revenue_with_gst * (1 - discount_pct)
# Step 7: Print total final_revenue

# YOUR CODE:

# %% [markdown]
# ---
# # ✅ COMPLETION CHECKLIST
#
# | Task | Done? |
# |------|-------|
# | 👁️ Watched: Data Manipulation & Analysis | |
# | 👁️ Watched: Data Source Reading | |
# | ⌨️ BUILD 1 — Full 10-step cleaning pipeline | |
# | ⌨️ BUILD 2 — apply() for salary band, experience, performance | |
# | ⌨️ BUILD 3 — String operations on emails | |
# | ⌨️ BUILD 4 — groupby with agg() | |
# | ⌨️ BUILD 5 — pivot_table vs groupby | |
# | ⌨️ BUILD 6 — Save/read CSV and JSON | |
# | ⌨️ BUILD 7 — Read tricky CSV with options | |
# | 🏋️ Practice Task 1 — Full sales pipeline | |
# | 🏋️ Practice Task 2 — Multi-source combine | |
# | 🗣️ All 5 EXPLAIN questions answered | |
# | 🧠 All THINK questions answered | |
