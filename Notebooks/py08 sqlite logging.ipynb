# %% [markdown]
# # 🗄️ py08_sqlite_logging.ipynb
# ### Phase 4 — Python for Data Engineering · Part 2
# **Topics:** Python with SQLite · Logging · Multiple Loggers · Real World Logging
#
# ---
# ```
# 👁️  WATCH    →  Understand the concept
# ⌨️  BUILD    →  Code it yourself — no copy paste
# 🗣️  EXPLAIN  →  Write it in plain English
# ```
# ---
#
# ## 🗣️ EXPLAIN BLOCK — Fill this LAST
#
# **Q1: What is SQLite and when would you use it instead of MySQL?**
#
# `YOUR ANSWER:`
#
# **Q2: What is the difference between `execute()` and `executemany()` in SQLite?**
#
# `YOUR ANSWER:`
#
# **Q3: What is the difference between a logging Handler and a Logger?**
#
# `YOUR ANSWER:`
#
# **Q4: Why use `logging` instead of `print()` in a real pipeline?**
#
# `YOUR ANSWER:`
#
# **Q5: What are the 5 logging levels and when do you use each?**
#
# `YOUR ANSWER:`

# %% [markdown]
# ---
# # SECTION 1 — SQLite Basics
# ---

# %%
import sqlite3

# ⌨️ BUILD 1 — Connect, Create, Insert

# 1. Connect to a database called 'company.db'
#    (SQLite creates the file automatically if it doesn't exist)
# YOUR CODE:

# 2. Create a cursor
# YOUR CODE:

# 3. Create a table 'employees' with:
#    id (INTEGER PRIMARY KEY AUTOINCREMENT)
#    name (TEXT NOT NULL)
#    dept (TEXT)
#    salary (REAL)
#    joining_date (TEXT)
# YOUR CODE:

# 4. Insert 5 rows one by one using execute()
# YOUR CODE:

# 5. Insert 3 more rows at once using executemany()
# YOUR CODE:

# 6. Commit and close connection
# YOUR CODE:

# %%
# ⌨️ BUILD 2 — Query the Database

conn = sqlite3.connect('company.db')
cur = conn.cursor()

# 1. Select ALL rows and print them
# YOUR CODE:

# 2. Select only name and salary where salary > 60000
# YOUR CODE:

# 3. Select top 3 highest paid employees (ORDER BY + LIMIT)
# YOUR CODE:

# 4. Count employees per department
# YOUR CODE:

# 5. Find average salary per department
# YOUR CODE:

conn.close()

# %%
# ⌨️ BUILD 3 — Update and Delete

conn = sqlite3.connect('company.db')
cur = conn.cursor()

# 1. Give a 10% salary raise to all employees in 'IT' dept
# YOUR CODE:

# 2. Delete employees with salary < 40000
# YOUR CODE:

# 3. Verify changes: print all rows after update/delete
# YOUR CODE:

conn.commit()
conn.close()

# %%
# ⌨️ BUILD 4 — SQLite + Pandas together
import pandas as pd

conn = sqlite3.connect('company.db')

# 1. Read entire employees table into a Pandas DataFrame using pd.read_sql()
# YOUR CODE:

# 2. Do a groupby analysis in Pandas: avg salary per dept
# YOUR CODE:

# 3. Create a NEW DataFrame with 5 rows and write it to a new SQLite table
#    using df.to_sql() — table name: 'departments'
# YOUR CODE:

# 4. Query both tables with a JOIN using pd.read_sql()
# YOUR CODE:

conn.close()

# %% [markdown]
# ## 🧠 THINK — SQLite
#
# **Q: SQLite doesn't support multiple concurrent writers. When would this be a problem in a data pipeline?**
#
# `YOUR ANSWER:`
#
# **Q: You forget to call `conn.commit()` after an INSERT. What happens?**
#
# `YOUR ANSWER:`
#
# **Q: What is parameterized query and why should you NEVER concatenate user input directly into a SQL string?**
#
# `YOUR ANSWER:`
#
# **SHOW IT:** Write a parameterized INSERT below — show the RIGHT way vs the WRONG (SQL injection vulnerable) way:
#
# ```python
# # WRONG way:
# name = "Robert'); DROP TABLE employees; --"
# # YOUR CODE showing why this is dangerous:
#
#
# # RIGHT way (parameterized):
# # YOUR CODE:
# ```

# %% [markdown]
# ---
# # SECTION 2 — Python Logging
# ---

# %%
import logging

# ⌨️ BUILD 5 — Basic Logging Setup

# 1. Configure basicConfig:
#    - Log to a file called 'app.log'
#    - Level: DEBUG
#    - Format: timestamp - level - message
# YOUR CODE:


# 2. Write one log at each level and explain WHEN you'd use it:
#    DEBUG   → for:
#    INFO    → for:
#    WARNING → for:
#    ERROR   → for:
#    CRITICAL → for:
# YOUR CODE:


# 3. Open and print 'app.log' to verify output
# YOUR CODE:

# %%
# ⌨️ BUILD 6 — Logger with Handlers
# (Better practice than basicConfig for real pipelines)

import logging

# Create a named logger
logger = logging.getLogger('pipeline_logger')
logger.setLevel(logging.DEBUG)

# 1. Add a FileHandler — writes DEBUG and above to 'pipeline.log'
# YOUR CODE:

# 2. Add a StreamHandler — writes WARNING and above to console
# YOUR CODE:

# 3. Create a formatter with: time - logger_name - level - message
#    Apply it to both handlers
# YOUR CODE:

# 4. Test by logging at all 5 levels:
#    Which ones appear in file vs console? Write a comment.
# YOUR CODE:

# %%
# ⌨️ BUILD 7 — Multiple Loggers
# Real pipelines have separate loggers for separate concerns

import logging

def setup_logger(name, log_file, level=logging.DEBUG):
    # YOUR CODE: Create and return a named logger
    # that writes to its own file with a timestamp format
    pass

# Create 3 loggers:
db_logger  = setup_logger('db_logger',  'db_events.log')
etl_logger = setup_logger('etl_logger', 'etl_events.log')
err_logger = setup_logger('error_logger', 'errors.log', level=logging.ERROR)

# Test them:
# YOUR CODE:
# db_logger  → log: connecting to DB, querying table, row count
# etl_logger → log: starting ETL, rows extracted, rows transformed, rows loaded
# err_logger → log: a simulated error (use logger.error() with exc_info=True)

# Then print contents of all 3 log files
# YOUR CODE:

# %% [markdown]
# ---
# # SECTION 3 — Real World: Logging Inside a Pipeline
# ---

# %%
# ⌨️ BUILD 8 — Log everything in an ETL pipeline
# Build a complete mini ETL that logs every step properly

import sqlite3
import pandas as pd
import logging

# Setup pipeline logger (to file + console)
# YOUR CODE:


def extract(filepath):
    """Read CSV file and return DataFrame"""
    # Log: starting extract, filename
    # Try to read file, catch FileNotFoundError and log it as ERROR
    # Log: rows extracted
    # YOUR CODE:
    pass


def transform(df):
    """Clean and transform data"""
    # Log: starting transform, rows before cleaning
    # Remove nulls
    # Remove duplicates
    # Add a 'processed_at' column with current timestamp
    # Log: rows after cleaning, rows dropped
    # YOUR CODE:
    pass


def load(df, db_name, table_name):
    """Load DataFrame into SQLite"""
    # Log: starting load, target db and table
    # Write to SQLite using to_sql()
    # Log: rows loaded successfully
    # Catch any exception and log as CRITICAL
    # YOUR CODE:
    pass


# Run the pipeline
# 1. Save your cleaned sales data from py07 as 'sales.csv' (or create a small one)
# 2. Run extract → transform → load
# 3. Check your log file
# YOUR CODE:

# %% [markdown]
# ## 🧠 THINK — Logging
#
# **Q: Your ETL pipeline runs at 2 AM via a cron job. Nobody is watching. Why is logging critical here?**
#
# `YOUR ANSWER:`
#
# **Q: What is `exc_info=True` in logging and when do you use it?**
#
# `YOUR ANSWER:`
#
# **Q: In a team of 5 engineers all writing to the same pipeline, why would you use named loggers instead of the root logger?**
#
# `YOUR ANSWER:`

# %% [markdown]
# ---
# # 🏋️ PRACTICE TASKS
# ---

# %%
# Practice Task 1 — Student Database + Logging
# Build a full CRUD system with logging for every operation

# 1. Create SQLite DB 'school.db' with table 'students':
#    id, name, age, grade, subject
#
# 2. Create a logger that logs to both 'school.log' AND console
#
# 3. Write functions (each must log on entry and exit):
#    - add_student(conn, name, age, grade, subject)
#    - get_top_students(conn, n)  → top n by grade
#    - update_grade(conn, student_id, new_grade)
#    - delete_student(conn, student_id)
#    - get_avg_grade_by_subject(conn)
#
# 4. Insert 10 students using add_student()
# 5. Call each function and verify logs
# 6. Print the contents of school.log at the end

# YOUR CODE:

# %%
# Practice Task 2 — Error Handling + Logging
# Write a function that:
#   1. Reads a CSV file
#   2. Validates: no nulls in 'id' column, age must be 0-120
#   3. Logs a WARNING for each validation issue found
#   4. Logs an ERROR and raises exception if file doesn't exist
#   5. Logs INFO at start and end with row counts
#
# Test it with:
#   a) A valid file
#   b) A file with validation issues
#   c) A file path that doesn't exist

# YOUR CODE:

# %% [markdown]
# ---
# # ✅ COMPLETION CHECKLIST
#
# | Task | Done? |
# |------|-------|
# | 👁️ Watched: Python with SQLite | |
# | 👁️ Watched: Logging in Python | |
# | 👁️ Watched: Logging with Multiple Loggers | |
# | 👁️ Watched: Logging — Real World Examples | |
# | ⌨️ BUILD 1 — Connect, create table, insert | |
# | ⌨️ BUILD 2 — Query with WHERE, ORDER BY, GROUP BY | |
# | ⌨️ BUILD 3 — UPDATE and DELETE | |
# | ⌨️ BUILD 4 — SQLite + Pandas read_sql + to_sql | |
# | ⌨️ BUILD 5 — Basic logging all 5 levels | |
# | ⌨️ BUILD 6 — Logger with File + Stream handlers | |
# | ⌨️ BUILD 7 — 3 separate named loggers | |
# | ⌨️ BUILD 8 — Full ETL pipeline with logging | |
# | 🏋️ Practice Task 1 — Student DB + logging | |
# | 🏋️ Practice Task 2 — Error handling + logging | |
# | 🗣️ All 5 EXPLAIN questions answered | |
# | 🧠 All THINK questions answered | |
# | 🧠 SQL injection example written | |
